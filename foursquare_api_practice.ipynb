# %%
import json
import requests
import pandas as pd
import pymongo

# %%
# Load secrets from credentials.json
url = 'https://api.foursquare.com/v2/venues/explore'
with open("/Users/jacobcrabb/.secret/Foursquare_api.json") as f:
    params = json.load(f)

# %%
params['v'] = '20180323'

params['ll'] = ' 47.6062, -122.3321'

params['query'] = 'Starbucks'
params['radius'] = 10000
params['limit'] = 1000
response = requests.get(url=url, params=params)
data = json.loads(response.text)

# %%
data
# Out:
# {'meta': {'code': 200, 'requestId': '5cc8cbe09fb6b756cdacfd6f'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Seattle',
#   'headerFullLocation': 'Seattle',
#   'headerLocationGranularity': 'city',
#   'query': 'starbucks',
#   'totalResults': 101,
#   'suggestedBounds': {'ne': {'lat': 47.69620009000009,
#     'lng': -122.19886200682382},
#    'sw': {'lat': 47.51619990999991, 'lng': -122.46533799317618}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58ad168cd8e55956ea9db67e',
#        'name': 'Starbucks Reserve Bar',
#        'contact': {},
#        'location': {'address': '1305 University Ave',
# ...

# %%
data['response'].keys()
# Out:
# dict_keys(['suggestedFilters', 'headerLocation', 'headerFullLocation', 'headerLocationGranularity', 'query', 'totalResults', 'suggestedBounds', 'groups'])

# %%
results = len(data['response']['groups'][0]['items'])

# %%
results
# Out:
# 100

# %%
for spot in range(results):
    print(data['response']['groups'][0]['items'][spot]['venue']['name'])
# Out:
# Starbucks Reserve Bar
# Starbucks
# Starbucks
# Starbucks Reserve
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks Reserve SoDo
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks Global Creative Studio
# Starbucks - Swedish Lobby
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# ...

# %%
lats = []
longs = []
for spot in range(results):
    lats.append(data['response']['groups'][0]['items'][spot]['venue']['location']['lat'])
    longs.append(data['response']['groups'][0]['items'][spot]['venue']['location']['lng'])
locations = list(zip(lats,longs))



import folium
from folium.plugins import HeatMap

lat = 47.605500
long = -122.330000

#Create a map of the area
base_map = folium.Map([lat, long],tiles='Stamen Terrain', zoom_start=15)
base_map




for location in locations:
    lat = location[0]
    long = location[1]

    marker = folium.Marker(location=[lat, long])
    marker.add_to(base_map)
    




# Plot it on the map
# HeatMap(locations).add_to(base_map)
    
    
for location in locations:
    lat = location[0]
    long = location[1]
    popup_text = "Quality: 5 Star, Price: 5 Star Price"
    popup = folium.Popup(popup_text, parse_html=True)
    marker = folium.Marker(location=[lat, long], popup=popup)

    marker.add_to(base_map)


marker = folium.Marker(location=[46.879967, -121.726906])
marker.add_to(base_map)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
lats = []
longs = []
for spot in range(results):
    lats.append(data['response']['groups'][0]['items'][spot]['venue']['location']['lat'])
    longs.append(data['response']['groups'][0]['items'][spot]['venue']['location']['lng'])
locations = list(zip(lats,longs))



import folium
from folium.plugins import HeatMap

lat = 47.605500
long = -122.330000

#Create a map of the area
base_map = folium.Map([lat, long],tiles='Stamen Terrain', zoom_start=15)
base_map




for location in locations:
    lat = location[0]
    long = location[1]

    marker = folium.Marker(location=[lat, long],
                           icon=folium.Icon(icon='cloud'))

    marker.add_to(base_map)
    



# Plot it on the map
# HeatMap(locations).add_to(base_map)
    
    
for location in locations:
    random_icon = np.random.choice(['cloud','info-sign'])
    random_color = np.random.choice(['blue','green','orange','black','pink'])
    lat = location[0]
    long = location[1]
    popup_text = "Quality: 5 Star, Price: 5 Star Price"
    popup = folium.Popup(popup_text, parse_html=True)
    marker = folium.Marker(location=[lat, long],
                           popup=popup,
                           icon=folium.Icon(color=random_color,icon=random_icon))

    marker.add_to(base_map)


marker = folium.Marker(location=[46.879967, -121.726906])
marker.add_to(base_map)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
lats = []
longs = []
for spot in range(results):
    lats.append(data['response']['groups'][0]['items'][spot]['venue']['location']['lat'])
    longs.append(data['response']['groups'][0]['items'][spot]['venue']['location']['lng'])
locations = list(zip(lats,longs))



import folium
from folium.plugins import HeatMap

lat = 47.605500
long = -122.330000

#Create a map of the area
base_map = folium.Map([lat, long],tiles='Stamen Terrain', zoom_start=15)
base_map




# for location in locations:
#     lat = location[0]
#     long = location[1]

#     marker = folium.Marker(location=[lat, long],
#                            icon=folium.Icon(icon='cloud'))

#     marker.add_to(base_map)
    



# Plot it on the map
# HeatMap(locations).add_to(base_map)
    
    
for location in locations:
    random_icon = np.random.choice(['cloud','info-sign'])
    random_color = np.random.choice(['blue','green','orange','black','pink'])
    lat = location[0]
    long = location[1]
    popup_text = "Quality: 5 Star, Price: 5 Star Price"
    popup = folium.Popup(popup_text, parse_html=True)
    marker = folium.Circle(location=[lat, long],
                           popup=popup,
                           radius=100,
                           color=random_color)

    marker.add_to(base_map)


marker = folium.Marker(location=[46.879967, -121.726906])
marker.add_to(base_map)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
lats = []
longs = []
for spot in range(results):
    lats.append(data['response']['groups'][0]['items'][spot]['venue']['location']['lat'])
    longs.append(data['response']['groups'][0]['items'][spot]['venue']['location']['lng'])
locations = list(zip(lats,longs))



import folium
from folium.plugins import HeatMap

lat = 47.605500
long = -122.330000

#Create a map of the area
base_map = folium.Map([lat, long],tiles='Stamen Terrain', zoom_start=15)
base_map




# for location in locations:
#     lat = location[0]
#     long = location[1]

#     marker = folium.Marker(location=[lat, long],
#                            icon=folium.Icon(icon='cloud'))

#     marker.add_to(base_map)
    



# Plot it on the map
# HeatMap(locations).add_to(base_map)
    
    
for location in locations:
    random_icon = np.random.choice(['cloud','info-sign'])
    random_color = np.random.choice(['blue','green','orange','black','pink'])
    lat = location[0]
    long = location[1]
    popup_text = "Quality: 5 Star, Price: 5 Star Price"
    popup = folium.Popup(popup_text, parse_html=True)
    marker = folium.(location=[lat, long],
                           popup=popup,
                           radius=100,
                           color=random_color)

    marker.add_to(base_map)


marker = folium.Marker(location=[46.879967, -121.726906])
marker.add_to(base_map)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker(
    location=[45.3288, -121.6625],
    popup='Mt. Hood Meadows',
    icon=folium.Icon(icon='cloud')
).add_to(m)

folium.Marker(
    location=[45.3311, -121.7113],
    popup='Timberline Lodge',
    icon=folium.Icon(color='green')
).add_to(m)

folium.Marker(
    location=[45.3300, -121.6823],
    popup='Some Other Location',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)
folium.Icon()
